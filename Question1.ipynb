# %%
string='''
Steve was born in Tokyo, Japan in 1950. He moved to London with his parents when he was 5 years old. Steve started school there and his father began work at the hospital. His mother was a house wife and he had four brothers.

He lived in England for 2 years then moved to Amman, Jordan where he lived there for 10 years. Steve then moved to Cyprus to study at the Mediterranean University. Unfortunately, he did not succeed and returned to Jordan. His parents were very unhappy so he decided to try in America.

He applied to many colleges and universities in the States and finally got some acceptance offers from them. He chose Wichita State University in Kansas. His major was Bio-medical Engineering. He stayed there for bout six months and then he moved again to a very small town called Greensboro to study in a small college.

'''

# %% [markdown]
# # 1. Lower

# %%
string.lower()
# Out:
# '\nsteve was born in tokyo, japan in 1950. he moved to london with his parents when he was 5 years old. steve started school there and his father began work at the hospital. his mother was a house wife and he had four brothers.\n\nhe lived in england for 2 years then moved to amman, jordan where he lived there for 10 years. steve then moved to cyprus to study at the mediterranean university. unfortunately, he did not succeed and returned to jordan. his parents were very unhappy so he decided to try in america.\n\nhe applied to many colleges and universities in the states and finally got some acceptance offers from them. he chose wichita state university in kansas. his major was bio-medical engineering. he stayed there for bout six months and then he moved again to a very small town called greensboro to study in a small college.\n\n'

# %% [markdown]
# # 2. Change numerals to their counter names

# %%
string='''
Steve was born in Tokyo, Japan in 1950. He moved to London with his parents when he
was 5 years old. Steve started school there and his father began work at the hospital.
His mother was a house wife and he had four brothers.
He lived in England for 2 years then moved to Amman, Jordan where he lived there for
10 years. Steve then moved to Cyprus to study at the Mediterranean University.
Unfortunately, he did not succeed and returned to Jordan. His parents were very
unhappy so he decided to try in America.
He applied to many colleges and universities in the States and finally got some
acceptance offers from them. He chose Wichita State University in Kansas. His major
was Bio-medical Engineering. He stayed there for bout six months and then he moved
again to a very small town called Greensboro to study in a small college.'''

num = [int(i) for i in string.split() if i.isdigit()] 
def int_to_en(num):
    d = { 0 : 'zero', 1 : 'one', 2 : 'two', 3 : 'three', 4 : 'four', 5 : 'five',
          6 : 'six', 7 : 'seven', 8 : 'eight', 9 : 'nine', 10 : 'ten',
          11 : 'eleven', 12 : 'twelve', 13 : 'thirteen', 14 : 'fourteen',
          15 : 'fifteen', 16 : 'sixteen', 17 : 'seventeen', 18 : 'eighteen',
          19 : 'nineteen', 20 : 'twenty',
          30 : 'thirty', 40 : 'forty', 50 : 'fifty', 60 : 'sixty',
          70 : 'seventy', 80 : 'eighty', 90 : 'ninety' }
    k = 1000
    m = k * 1000
    b = m * 1000
    t = b * 1000

    assert(0 <= num)

    if (num < 20):
        return d[num]

    if (num < 100):
        if num % 10 == 0: return d[num]
        else: return d[num // 10 * 10] + '-' + d[num % 10]

    if (num < k):
        if num % 100 == 0: return d[num // 100] + ' hundred'
        else: return d[num // 100] + ' hundred and ' + int_to_en(num % 100)

    if (num < m):
        if num % k == 0: return int_to_en(num // k) + ' thousand'
        else: return int_to_en(num // k) + ' thousand, ' + int_to_en(num % k)

    if (num < b):
        if (num % m) == 0: return int_to_en(num // m) + ' million'
        else: return int_to_en(num // m) + ' million, ' + int_to_en(num % m)

    if (num < t):
        if (num % b) == 0: return int_to_en(num // b) + ' billion'
        else: return int_to_en(num // b) + ' billion, ' + int_to_en(num % b)

    if (num % t == 0): return int_to_en(num // t) + ' trillion'
    else: return int_to_en(num // t) + ' trillion, ' + int_to_en(num % t)
for i in (num):
    print(i,':',int_to_en(i))
# Out:
# 5 : five
# 2 : two
# 10 : ten

# %% [markdown]
# # 3. Remove Punctuations

# %%
import re
s = '''
Steve was born in Tokyo, Japan in 1950. He moved to London with his parents when he was 5 years old. Steve started school there and his father began work at the hospital. His mother was a house wife and he had four brothers.

He lived in England for 2 years then moved to Amman, Jordan where he lived there for 10 years. Steve then moved to Cyprus to study at the Mediterranean University. Unfortunately, he did not succeed and returned to Jordan. His parents were very unhappy so he decided to try in America.

He applied to many colleges and universities in the States and finally got some acceptance offers from them. He chose Wichita State University in Kansas. His major was Bio-medical Engineering. He stayed there for bout six months and then he moved again to a very small town called Greensboro to study in a small college.'''
s = re.sub(r'[^\w\s]','',s)

# %%
s
# Out:
# '\nSteve was born in Tokyo Japan in 1950 He moved to London with his parents when he was 5 years old Steve started school there and his father began work at the hospital His mother was a house wife and he had four brothers\n\nHe lived in England for 2 years then moved to Amman Jordan where he lived there for 10 years Steve then moved to Cyprus to study at the Mediterranean University Unfortunately he did not succeed and returned to Jordan His parents were very unhappy so he decided to try in America\n\nHe applied to many colleges and universities in the States and finally got some acceptance offers from them He chose Wichita State University in Kansas His major was Biomedical Engineering He stayed there for bout six months and then he moved again to a very small town called Greensboro to study in a small college'

# %% [markdown]
# # 4. Remove whitespaces

# %%
s = '''
Steve was born in Tokyo, Japan in 1950. He moved to London with his parents when he was 5 years old. Steve started school there and his father began work at the hospital. His mother was a house wife and he had four brothers.

He lived in England for 2 years then moved to Amman, Jordan where he lived there for 10 years. Steve then moved to Cyprus to study at the Mediterranean University. Unfortunately, he did not succeed and returned to Jordan. His parents were very unhappy so he decided to try in America.

He applied to many colleges and universities in the States and finally got some acceptance offers from them. He chose Wichita State University in Kansas. His major was Bio-medical Engineering. He stayed there for bout six months and then he moved again to a very small town called Greensboro to study in a small college.'''
s.replace(" ", "")
# Out:
# '\nStevewasborninTokyo,Japanin1950.HemovedtoLondonwithhisparentswhenhewas5yearsold.Stevestartedschoolthereandhisfatherbeganworkatthehospital.Hismotherwasahousewifeandhehadfourbrothers.\n\nHelivedinEnglandfor2yearsthenmovedtoAmman,Jordanwherehelivedtherefor10years.StevethenmovedtoCyprustostudyattheMediterraneanUniversity.Unfortunately,hedidnotsucceedandreturnedtoJordan.HisparentswereveryunhappysohedecidedtotryinAmerica.\n\nHeappliedtomanycollegesanduniversitiesintheStatesandfinallygotsomeacceptanceoffersfromthem.HechoseWichitaStateUniversityinKansas.HismajorwasBio-medicalEngineering.HestayedthereforboutsixmonthsandthenhemovedagaintoaverysmalltowncalledGreensborotostudyinasmallcollege.'

# %% [markdown]
# # 5. Stemming

# %%
import nltk
nltk.download('punkt')
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize
from nltk.stem.porter import PorterStemmer
porter_stemmer = PorterStemmer()
string='''
Steve was born in Tokyo, Japan in 1950. He moved to London with his parents when he was 5 years old. Steve started school there and his father began work at the hospital. His mother was a house wife and he had four brothers.

He lived in England for 2 years then moved to Amman, Jordan where he lived there for 10 years. Steve then moved to Cyprus to study at the Mediterranean University. Unfortunately, he did not succeed and returned to Jordan. His parents were very unhappy so he decided to try in America.

He applied to many colleges and universities in the States and finally got some acceptance offers from them. He chose Wichita State University in Kansas. His major was Bio-medical Engineering. He stayed there for bout six months and then he moved again to a very small town called Greensboro to study in a small college.
'''
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELLS\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.

# %%
sentence='''
Steve was born in Tokyo, Japan in 1950. He moved to London with his parents when he was 5 years old. Steve started school there and his father began work at the hospital. His mother was a house wife and he had four brothers.

He lived in England for 2 years then moved to Amman, Jordan where he lived there for 10 years. Steve then moved to Cyprus to study at the Mediterranean University. Unfortunately, he did not succeed and returned to Jordan. His parents were very unhappy so he decided to try in America.

He applied to many colleges and universities in the States and finally got some acceptance offers from them. He chose Wichita State University in Kansas. His major was Bio-medical Engineering. He stayed there for bout six months and then he moved again to a very small town called Greensboro to study in a small college.'''
words = word_tokenize(sentence)
ps = PorterStemmer()
for w in words:
    
    rootWord=ps.stem(w)
    print(rootWord)
# Out:
# steve
# wa
# born
# in
# tokyo
# ,
# japan
# in
# 1950
# .
# He
# move
# to
# london
# with
# hi
# parent
# when
# he
# wa
# 5
# year
# old
# .
# steve
# start
# school
# there
# and
# hi
# father
# began
# work
# at
# the
# hospit
# .
# hi
# mother
# wa
# a
# hous
# wife
# and
# he
# had
# four
# brother
# .
# He
# live
# in
# england
# for
# 2
# year
# then
# move
# to
# amman
# ,
# jordan
# where
# he
# live
# there
# for
# 10
# year
# .
# steve
# then
# move
# to
# cypru
# to
# studi
# at
# the
# mediterranean
# univers
# .
# unfortun
# ,
# he
# did
# not
# succeed
# and
# return
# to
# jordan
# .
# hi
# parent
# were
# veri
# unhappi
# so
# he
# decid
# to
# tri
# in
# america
# .
# He
# appli
# to
# mani
# colleg
# and
# univers
# in
# the
# state
# and
# final
# got
# some
# accept
# offer
# from
# them
# .
# He
# chose
# wichita
# state
# univers
# in
# kansa
# .
# hi
# major
# wa
# bio-med
# engin
# .
# He
# stay
# there
# for
# bout
# six
# month
# and
# then
# he
# move
# again
# to
# a
# veri
# small
# town
# call
# greensboro
# to
# studi
# in
# a
# small
# colleg
# .

# %% [markdown]
# # 6. Lemmatization

# %%
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()
text = '''
Steve was born in Tokyo, Japan in 1950. He moved to London with his parents when he was 5 years old. Steve started school there and his father began work at the hospital. His mother was a house wife and he had four brothers.

He lived in England for 2 years then moved to Amman, Jordan where he lived there for 10 years. Steve then moved to Cyprus to study at the Mediterranean University. Unfortunately, he did not succeed and returned to Jordan. His parents were very unhappy so he decided to try in America.

He applied to many colleges and universities in the States and finally got some acceptance offers from them. He chose Wichita State University in Kansas. His major was Bio-medical Engineering. He stayed there for bout six months and then he moved again to a very small town called Greensboro to study in a small college.
'''
tokenization = nltk.word_tokenize(text)
for w in tokenization:
    print("Lemma for {} is {}".format(w, wordnet_lemmatizer.lemmatize(w)))
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\DELLS\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# Lemma for Steve is Steve
# Lemma for was is wa
# Lemma for born is born
# Lemma for in is in
# Lemma for Tokyo is Tokyo
# Lemma for , is ,
# Lemma for Japan is Japan
# Lemma for in is in
# Lemma for 1950 is 1950
# Lemma for . is .
# Lemma for He is He
# Lemma for moved is moved
# Lemma for to is to
# Lemma for London is London
# Lemma for with is with
# Lemma for his is his
# Lemma for parents is parent
# Lemma for when is when
# Lemma for he is he
# Lemma for was is wa
# Lemma for 5 is 5
# Lemma for years is year
# Lemma for old is old
# Lemma for . is .
# Lemma for Steve is Steve
# Lemma for started is started
# Lemma for school is school
# Lemma for there is there
# Lemma for and is and
# Lemma for his is his
# Lemma for father is father
# Lemma for began is began
# Lemma for work is work
# Lemma for at is at
# Lemma for the is the
# Lemma for hospital is hospital
# Lemma for . is .
# Lemma for His is His
# Lemma for mother is mother
# Lemma for was is wa
# Lemma for a is a
# Lemma for house is house
# Lemma for wife is wife
# Lemma for and is and
# Lemma for he is he
# Lemma for had is had
# Lemma for four is four
# Lemma for brothers is brother
# Lemma for . is .
# Lemma for He is He
# Lemma for lived is lived
# Lemma for in is in
# Lemma for England is England
# Lemma for for is for
# Lemma for 2 is 2
# Lemma for years is year
# Lemma for then is then
# Lemma for moved is moved
# Lemma for to is to
# Lemma for Amman is Amman
# Lemma for , is ,
# Lemma for Jordan is Jordan
# Lemma for where is where
# Lemma for he is he
# Lemma for lived is lived
# Lemma for there is there
# Lemma for for is for
# Lemma for 10 is 10
# Lemma for years is year
# Lemma for . is .
# Lemma for Steve is Steve
# Lemma for then is then
# Lemma for moved is moved
# Lemma for to is to
# Lemma for Cyprus is Cyprus
# Lemma for to is to
# Lemma for study is study
# Lemma for at is at
# Lemma for the is the
# Lemma for Mediterranean is Mediterranean
# Lemma for University is University
# Lemma for . is .
# Lemma for Unfortunately is Unfortunately
# Lemma for , is ,
# Lemma for he is he
# Lemma for did is did
# Lemma for not is not
# Lemma for succeed is succeed
# Lemma for and is and
# Lemma for returned is returned
# Lemma for to is to
# Lemma for Jordan is Jordan
# Lemma for . is .
# Lemma for His is His
# Lemma for parents is parent
# Lemma for were is were
# Lemma for very is very
# Lemma for unhappy is unhappy
# Lemma for so is so
# Lemma for he is he
# Lemma for decided is decided
# Lemma for to is to
# Lemma for try is try
# Lemma for in is in
# Lemma for America is America
# Lemma for . is .
# Lemma for He is He
# Lemma for applied is applied
# Lemma for to is to
# Lemma for many is many
# Lemma for colleges is college
# Lemma for and is and
# Lemma for universities is university
# Lemma for in is in
# Lemma for the is the
# Lemma for States is States
# Lemma for and is and
# Lemma for finally is finally
# Lemma for got is got
# Lemma for some is some
# Lemma for acceptance is acceptance
# Lemma for offers is offer
# Lemma for from is from
# Lemma for them is them
# Lemma for . is .
# Lemma for He is He
# Lemma for chose is chose
# Lemma for Wichita is Wichita
# Lemma for State is State
# Lemma for University is University
# Lemma for in is in
# Lemma for Kansas is Kansas
# Lemma for . is .
# Lemma for His is His
# Lemma for major is major
# Lemma for was is wa
# Lemma for Bio-medical is Bio-medical
# Lemma for Engineering is Engineering
# Lemma for . is .
# Lemma for He is He
# Lemma for stayed is stayed
# Lemma for there is there
# Lemma for for is for
# Lemma for bout is bout
# Lemma for six is six
# Lemma for months is month
# Lemma for and is and
# Lemma for then is then
# Lemma for he is he
# Lemma for moved is moved
# Lemma for again is again
# Lemma for to is to
# Lemma for a is a
# Lemma for very is very
# Lemma for small is small
# Lemma for town is town
# Lemma for called is called
# Lemma for Greensboro is Greensboro
# Lemma for to is to
# Lemma for study is study
# Lemma for in is in
# Lemma for a is a
# Lemma for small is small
# Lemma for college is college
# Lemma for . is .
